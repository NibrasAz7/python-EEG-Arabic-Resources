# %% [markdown]
# # Shared EEG Data Loader Function
#
# **Topic**: Using load_local_eeg() to load real data from PhysioNet
#
# ---
#
# ## Overview
#
# We created a unified function in utils/eeg_loader.py that reads WFDB files and returns data in a consistent format. It takes the data path, subject number, and experiment number, and returns timestamps, signals, and channel names. All chapters in the book use this function.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install wfdb numpy

# %% [markdown]
# ## 2. Clone repository and download data

# %%
import os
from pathlib import Path

# Clone the resources repository (if not already cloned)
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git

os.chdir('python-EEG-Arabic-Resources')

# Download subject 7 data if not present
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# ## 3. Load data using load_local_eeg()

# %%
from utils.eeg_loader import load_local_eeg

# Load subject 7, experiment 1, session 2
timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local',
    subject=7,
    experiment=1,
    session=2
)

print(f'Signals shape: {eeg_data.shape}')
print(f'Channels: {ch_names}')
print(f'Duration: {eeg_data.shape[0] / 200:.1f} seconds')
print(f'Sampling rate: 200 Hz')

# Access first channel (P4)
p4_signal = eeg_data[:, 0]
print(f'P4 signal - mean: {p4_signal.mean():.2f} uV')
print(f'P4 signal - std:  {p4_signal.std():.2f} uV')

# %% [markdown]
# ## Summary
#
# - The function hides WFDB file reading details behind a simple interface
# - Returns a signals array of shape (n_samples, n_channels) and channel names list
# - All book chapters use this function, avoiding repeated file-reading code
# - This approach follows the DRY (Don't Repeat Yourself) principle
