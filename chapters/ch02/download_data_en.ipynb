# %% [markdown]
# # Download EEG Data from PhysioNet
#
# **Dataset**: PhysioNet auditory-eeg/1.0.0
#
# ---
#
# ## Overview
#
# This book uses the auditory EEG dataset published on PhysioNet. The dataset contains recordings from 20 subjects, each with 4 channels (P4, Cz, F8, T7) at 200 Hz sampling rate. This notebook downloads subject 7 data.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install wfdb numpy

# %% [markdown]
# ## 2. Clone repository and download data

# %%
import os
from pathlib import Path

# Clone the resources repository (if not already cloned)
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git

os.chdir('python-EEG-Arabic-Resources')

# Download subject 7 data
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# Verify download
dat_files = list(data_dir.glob('s07_*.dat'))
print(f'Downloaded {len(dat_files)} recordings for subject 7')
for f in sorted(dat_files):
    print(f'  {f.name}')

# %% [markdown]
# ## Summary
#
# - The dataset is available in WFDB format as .dat and .hea file pairs
# - The download script skips experiments not available for all subjects
# - Subject 7 data is sufficient for all book examples
