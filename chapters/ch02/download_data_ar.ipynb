# %% [markdown]
# <div dir="rtl" align="right">
#
# # تنزيلُ بياناتِ `EEG` من `PhysioNet`
#
# **المجموعة**: `PhysioNet auditory-eeg/1.0.0`
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# يَستخدمُ هذا الكتابُ مجموعةَ البياناتِ السمعيّةَ المنشورةَ على `PhysioNet`. تَحتوي المجموعةُ على تسجيلاتٍ من عشرينَ مشاركاً، كلٌّ منها بأربعِ قنواتٍ `(P4, Cz, F8, T7)` وبمعدّلِ أخذِ عيناتٍ 200 `Hz`. يُنزّلُ هذا الدفترُ بياناتِ المُشاركِ السابعِ `(subject 7)`.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install wfdb numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
from pathlib import Path

# Clone the resources repository (if not already cloned)
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git

os.chdir('python-EEG-Arabic-Resources')

# Download subject 7 data
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# Verify download
dat_files = list(data_dir.glob('s07_*.dat'))
print(f'Downloaded {len(dat_files)} recordings for subject 7')
for f in sorted(dat_files):
    print(f'  {f.name}')

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - مجموعةُ البياناتِ مُتوفّرةٌ بصيغةِ `WFDB` كأزواجٍ `.dat` و`.hea`
# - نصُّ التنزيلِ يَتخطّى التجاربَ غيرَ المتوفّرةِ لبعضِ المُشاركين
# - بياناتُ المُشاركِ السابعِ تَكفي لجميعِ أمثلةِ الكتاب
#
# </div>
