# %% [markdown]
# <div dir="rtl" align="right">
#
# # دالةُ تحميلِ بياناتِ `EEG` المُخصّصةُ
#
# **الموضوع**: استخدامُ `load_local_eeg()` لتحميلِ بياناتٍ حقيقيّةٍ من `PhysioNet`
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# أَنشأنا دالةً موحّدةً في `utils/eeg_loader.py` تَقرأُ ملفّاتِ `WFDB` وتُعيدُ البياناتَ بصيغةٍ موحّدة. تَأخذُ مسارَ البياناتِ ورقمَ المُشاركِ ورقمَ التجربة، وتُعيدُ الطوابعَ الزمنيّةَ والإشاراتِ وأسماءَ القنوات. تَستخدمُها جميعُ فصولِ الكتاب.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install wfdb numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
from pathlib import Path

# Clone the resources repository (if not already cloned)
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git

os.chdir('python-EEG-Arabic-Resources')

# Download subject 7 data if not present
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. تحميلُ البياناتِ باستخدامِ `load_local_eeg()`
#
# </div>

# %%
from utils.eeg_loader import load_local_eeg

# Load subject 7, experiment 1, session 2
timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local',
    subject=7,
    experiment=1,
    session=2
)

print(f'Signals shape: {eeg_data.shape}')
print(f'Channels: {ch_names}')
print(f'Duration: {eeg_data.shape[0] / 200:.1f} seconds')
print(f'Sampling rate: 200 Hz')

# Access first channel (P4)
p4_signal = eeg_data[:, 0]
print(f'P4 signal - mean: {p4_signal.mean():.2f} uV')
print(f'P4 signal - std:  {p4_signal.std():.2f} uV')

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - الدالةُ تُخفي تفاصيلَ قراءةِ ملفّاتِ `WFDB` خلفَ واجهةٍ بسيطة
# - تُعيدُ مصفوفةَ إشاراتٍ بُعدُها `(n_samples, n_channels)` وقائمةَ أسماءِ قنوات
# - جميعُ فصولِ الكتابِ تَستخدمُ هذه الدالةَ، فلا حاجةَ لإعادةِ كتابةِ كودِ القراءة
# - هذا النهجُ يُحقّقُ مبدأَ عدمِ التكرارِ `(DRY)`
#
# </div>
