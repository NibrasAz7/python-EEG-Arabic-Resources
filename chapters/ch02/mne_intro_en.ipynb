# %% [markdown]
# # Introduction to MNE-Python
#
# **Topic**: Creating a Raw object, inspecting EEG data
#
# ---
#
# ## Overview
#
# MNE-Python is a specialized library for brain data analysis. This notebook demonstrates creating a Raw object from synthetic data and inspecting its properties.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install mne numpy

# %% [markdown]
# ## 2. Create a Raw object

# %%
import numpy as np
import mne

# Create a synthetic EEG signal (4 channels, 10 seconds, 200 Hz)
fs = 200
n_samples = fs * 10
np.random.seed(42)
data = np.random.randn(4, n_samples) * 50  # 50 uV scale

# Create MNE Raw object
info = mne.create_info(
    ch_names=['P4', 'Cz', 'F8', 'T7'],
    sfreq=fs,
    ch_types='eeg'
)
raw = mne.io.RawArray(data, info)

print(raw)
print(f'Channels: {raw.ch_names}')
print(f'Duration: {raw.times[-1]:.1f} s')
print(f'Sampling rate: {raw.info["sfreq"]} Hz')

# Get data as numpy array
data_out, times = raw.get_data(return_times=True)
print(f'Data shape: {data_out.shape}')
print(f'Times shape: {times.shape}')

# %% [markdown]
# ## Summary
#
# - The Raw object stores continuous signal data with channel info and sampling rate
# - mne.create_info() defines channel names, types, and sampling frequency
# - raw.get_data() returns the data as a NumPy array for direct processing
