# %% [markdown]
# <div dir="rtl" align="right">
#
# # استكشافُ مجموعةِ بياناتٍ كثيفةِ القنواتِ `MNE sample`
#
# **الموضوع**: تصويرٌ طوبوغرافيٌّ دقيقٌ باستخدامِ 60 قناةً من مجموعةِ `MNE sample`
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# أَظهرَ المثالُ السابقُ أنَّ أربعَ قنواتٍ لا تَكفي لخريطةٍ طوبوغرافيّةٍ دقيقة. نَستعرضُ هنا مجموعةَ `MNE sample` التي تَحتوي على 60 قناةً معَ تركيبِ أقطابٍ كاملٍ.
#
# **البيانات**: `MNE sample dataset`، 60 قناة EEG، تجربةٌ سمعيّةٌ بصريّةٌ، تركيبٌ 10-20 مُعدٌّ مُسبقاً
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install mne matplotlib

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. تنزيلُ مجموعةِ البياناتِ وتحميلُها
#
# مجموعةُ `MNE sample` تُنزّلُ تلقائيّاً عبرَ دالةٍ واحدة. حجمُها نحوَ 1.5 غيغابايت (تنزيلٌ لمرةٍ واحدة).
#
# </div>

# %%
import mne
import matplotlib.pyplot as plt

# Download the MNE sample dataset (1.5 GB, one-time download)
sample_path = mne.datasets.sample.data_path()

# Load the EEG data (60 channels, pre-configured montage)
raw_fname = sample_path / 'MEG' / 'sample' / 'sample_audvis_raw.fif'
raw = mne.io.read_raw_fif(raw_fname, preload=True)

# Pick only EEG channels (exclude MEG and other channels)
raw.pick_types(eeg=True)

print(f'Number of EEG channels: {len(raw.ch_names)}')
print(f'Channel names: {raw.ch_names[:10]} ...')
print(f'Sampling rate: {raw.info["sfreq"]} Hz')
print(f'Duration: {raw.times[-1]:.1f} s')
print(f'Montage: {raw.get_montage()}')

# Create epochs around auditory events (event ID 1 = standard tone)
events = mne.find_events(raw, stim_channel='STI 014')
epochs = mne.Epochs(raw, events, event_id=1, tmin=-0.2, tmax=0.5,
                    preload=True)

# Compute evoked response (average across epochs)
evoked = epochs.average()

# Plot topomap at multiple time points
fig = evoked.plot_topomap(times=[0.0, 0.1, 0.2, 0.3],
                          ch_type='eeg',
                          time_unit='s',
                          size=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. شرحُ الخطواتِ
#
# - `mne.datasets.sample.data_path()`: تُنزّلُ البياناتِ وتُعيدُ مسارَها
# - `read_raw_fif`: تَقرأُ الملفَّ بصيغةِ `FIF` الخاصةَ بـ`MNE`
# - `pick_types(eeg=True)`: تَستبعدُ قنواتِ `MEG` وغيرَها، تُبقي `EEG` فقط
# - `find_events`: تَبحثُ عن لحظاتِ المُحفّزاتِ في القناةِ `STI 014`
# - `Epochs`: تَقطعُ الإشارةَ إلى مقاطعَ حولَ كلِّ مُحفّزٍ (-0.2 إلى +0.5 ثانية)
# - `average()`: تَحسبُ متوسطَ المقاطعِ لإبرازِ النشاطِ المُحفّزِ الثابت
# - `plot_topomap`: تَرسمُ الخريطةَ الطوبوغرافيّةَ في لحظاتٍ مُحدّدة
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ### علامَ تلاحظ؟
# - الفرقَ الكبيرَ في دقّةِ الخريطةِ مقارنةً بأربعِ قنواتٍ فقط
# - توزيعَ النشاطِ على فروةِ الرأسِ في لحظاتٍ مختلفةٍ بعدَ المُحفّزِ
# - الألوانَ تَتدرّجُ من الأحمرِ (موجب) إلى الأزرقِ (سالب)
# - الاستيفاءَ المكانيَّ يَملأُ الفراغاتِ بينَ الأقطابِ بسلاسة
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - كثافةُ القنواتِ تُحدّدُ دقّةَ الخريطةِ الطوبوغرافيّة: 60 قناةً تُنتجُ خرائطَ سلسةً ومُعبّرة
# - التركيبُ الكهربائيُّ `(montage)` يُحدّدُ مواقعَ الأقطابِ ثلاثيّةَ الأبعادِ على فروةِ الرأس
# - الجهودُ المرتبطةُ بالحدثِ `(ERP)` تُنتجُ خرائطَ أنظفَ من الإشارةِ المستمرّة
# - النظامُ `10-20` يُسمّي القنواتِ وفقَ مواقعَها التشريحيّة: `F` للجبهيّ، `C` للمركزيّ، `P` للجداريّ، `T` للصدغيّ، `O` للقفويّ
#
# </div>
