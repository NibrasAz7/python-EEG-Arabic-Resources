# %% [markdown]
# <div dir="rtl" align="right">
#
# # تصويرُ الإشارةِ الخامِ في المجالِ الزمنيّ
#
# **الموضوع**: رسمُ القنواتِ الأربعِ كمخططاتٍ زمنيّةٍ متتابعة
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# نَرسمُ كلَّ قناةٍ في مخططٍ زمنيٍّ يُظهرُ السعةَ كدالّةٍ في الزمن. هذا أبسطُ تصويرٍ للإشارةِ ويُكشفُ عن الانجرافِ والآثارِ الشائبة.
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install plotly wfdb numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git
os.chdir('python-EEG-Arabic-Resources')

# %%
from pathlib import Path
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. تصويرُ الإشارةِ الخام
#
# ### علامَ تلاحظ؟
# - الفرقَ في المتوسّطاتِ بينَ القنوات (انجراف)
# - تذبذباتٍ سريعةٍ تَنتمي إلى نطاقاتٍ تردديّةٍ مختلفة
# - المحورَ الأفقيَّ بالثواني والمحورَ العموديَّ بالمايكروفولت
#
# </div>

# %%
import sys
sys.path.insert(0, '.')
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from utils.eeg_loader import load_local_eeg

timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local', subject=7, experiment=1, session=2
)

fs = 200
time_sec = np.arange(eeg_data.shape[0]) / fs

fig = make_subplots(rows=4, cols=1, shared_xaxes=True)
for i, ch in enumerate(ch_names):
    fig.add_trace(
        go.Scatter(x=time_sec, y=eeg_data[:, i], mode='lines',
                   line=dict(width=0.5, color='steelblue'), name=ch),
        row=i+1, col=1
    )
    fig.update_yaxes(title_text=f'{ch} (uV)', row=i+1, col=1)

fig.update_xaxes(title_text='Time (s)', row=4, col=1)
fig.update_layout(title='Raw EEG Signal - Subject 7, Experiment 1', height=800)
fig.show()

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - المخططُ الزمنيُّ أبسطُ تصويرٍ للإشارة
# - يُكشفُ عن الانجرافِ والآثارِ الشائبة
# - القناةُ `P4` تُظهرُ متوسّطاً سالباً واضحاً
#
# </div>
