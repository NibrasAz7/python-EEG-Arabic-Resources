# %% [markdown]
# <div dir="rtl" align="right">
#
# # تحويلُ البياناتِ إلى كائنِ `Raw` في `MNE-Python`
#
# **الموضوع**: إنشاءُ `mne.io.RawArray` من بياناتِ `WFDB` المحمّلةِ عبرَ `load_local_eeg()`
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# مكتبةُ `MNE-Python` تُوفّرُ بنيةَ `Raw` التي تُخزّنُ الإشارةَ معَ معلوماتٍ وصفية. نَنشئُ هذه البنية من المصفوفةِ التي حَمّلناها.
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install mne wfdb numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git
os.chdir('python-EEG-Arabic-Resources')

# %%
from pathlib import Path
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. إنشاءُ كائنِ `Raw`
#
# ملاحظةٌ: `MNE` تَتوقّعُ البياناتِ بُعدَ `(n_channels, n_samples)`، لذلك نَستخدمُ `eeg_data.T` لتبديلِ الأبعاد.
#
# </div>

# %%
import sys
sys.path.insert(0, '.')
import mne
from utils.eeg_loader import load_local_eeg

timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local', subject=7, experiment=1, session=2
)

info = mne.create_info(ch_names=ch_names, sfreq=200, ch_types='eeg')
raw = mne.io.RawArray(eeg_data.T, info)

print(raw)
print(f'Channels: {raw.ch_names}')
print(f'Duration: {raw.times[-1]:.1f} s')

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - كائنُ `Raw` يُخزّنُ الإشارةَ معَ معلوماتٍ وصفية (أسماءُ القنوات، معدّلُ العينات)
# - `MNE` تَتوقّعُ البُعدَ `(channels, samples)` بينما `load_local_eeg` تُعيدُ `(samples, channels)`
# - نَستخدمُ `.T` لتبديلِ الأبعاد
#
# </div>
