# %% [markdown]
# <div dir="rtl" align="right">
#
# # التوزيعُ المكانيُّ لنشاطِ الدماغِ على فروةِ الرأس
#
# **الموضوع**: تصويرُ الخريطةِ الطوبوغرافيّةِ باستخدامِ `MNE-Python`
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# الخريطةُ الطوبوغرافيّةُ تُسقطُ النشاطَ الكهربائيَّ على سطحِ فروةِ الرأسِ باستخدامِ مواقعِ الأقطابِ وفقَ النظامِ `10-20`. بأربعِ قنواتٍ فقط، تَكونُ الخريطةُ تقريبيّةً (الغرضُ تعليميّ).
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install mne wfdb matplotlib numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git
os.chdir('python-EEG-Arabic-Resources')

# %%
from pathlib import Path
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. رسمُ الخريطةِ الطوبوغرافيّة
#
# ### علامَ تلاحظ؟
# - توزيعَ الطاقةِ الطيفيّةِ على مواقعِ الأقطابِ الأربعة
# - الخريطةَ تقريبيّةٌ لأنَّ أربعَ قنواتٍ لا تَكفي لاستيفاءٍ مكانيٍّ دقيق
# - في الدراساتِ السريريّةِ يُستخدمُ 32 أو 64 قناةً لدقّةٍ أعلى
#
# </div>

# %%
import sys
sys.path.insert(0, '.')
import matplotlib.pyplot as plt
import mne
from utils.eeg_loader import load_local_eeg

timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local', subject=7, experiment=1, session=2
)

info = mne.create_info(ch_names=ch_names, sfreq=200, ch_types='eeg')
raw = mne.io.RawArray(eeg_data.T, info)

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')

fig = raw.compute_psd().plot_topomap()
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - الخريطةُ الطوبوغرافيّةُ تُسقطُ النشاطَ على فروةِ الرأس
# - بأربعِ قنواتٍ فقط، تَكونُ تقريبيّةً (الغرضُ تعليميّ)
# - تَستخدمُ مواقعَ الأقطابِ وفقَ النظامِ `10-20` للاستيفاءِ المكانيّ
#
# </div>
