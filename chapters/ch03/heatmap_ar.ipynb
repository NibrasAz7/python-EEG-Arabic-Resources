# %% [markdown]
# <div dir="rtl" align="right">
#
# # الخريطةُ الحراريّةُ لبياناتِ `EEG`
#
# **الموضوع**: تصويرُ السعةِ عبرَ القنواتِ والزمنِ بألوانٍ متدرّجة
#
# ---
#
# ## نظرةٌ عامّةٌ
#
# الخريطةُ الحراريّةُ تُمثّلُ البياناتِ ثنائيّةَ الأبعادِ بألوانٍ تَتدرّجُ بحسبِ السعة. تُكشفُ عن أنماطٍ يَصعبُ رصدها في المخططاتِ الزمنيّة.
#
# ## 1. تثبيتُ المكتباتِ
#
# </div>

# %%
# !pip install matplotlib wfdb numpy

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2. استنساخُ المستودعِ وتنزيلُ البيانات
#
# </div>

# %%
import os
if not os.path.exists('python-EEG-Arabic-Resources'):
    # !git clone https://github.com/NibrasAz7/python-EEG-Arabic-Resources.git
os.chdir('python-EEG-Arabic-Resources')

# %%
from pathlib import Path
data_dir = Path('data/local')
if not data_dir.exists() or not any(data_dir.glob('*.dat')):
    # !python data/download_local.py --output data/local --subjects 7

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3. إنشاءُ الخريطةِ الحراريّة
#
# ### علامَ تلاحظ؟
# - المناطقَ الزمنيّةَ ذاتَ السعاتِ المرتفعة (ألوانٌ أكثرُ تشبّعاً)
# - الانجرافَ في القناةِ `P4` كمنطقةٍ زرقاءَ مستمرّة
# - التزامنَ بينَ القنواتِ في لحظاتٍ معيّنة
#
# </div>

# %%
import sys
sys.path.insert(0, '.')
import matplotlib.pyplot as plt
from utils.eeg_loader import load_local_eeg

timestamps, eeg_data, ch_names = load_local_eeg(
    data_dir='data/local', subject=7, experiment=1, session=2
)

fig, ax = plt.subplots(figsize=(12, 4))
im = ax.imshow(
    eeg_data.T, aspect='auto', cmap='RdBu_r',
    vmin=-100, vmax=100,
    extent=[0, eeg_data.shape[0]/200, 4, 0]
)
ax.set_yticks([0.5, 1.5, 2.5, 3.5])
ax.set_yticklabels(ch_names)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Channel')
ax.set_title('EEG Heatmap - Subject 7')
plt.colorbar(im, ax=ax, label='Amplitude (uV)')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## خلاصةٌ
#
# - الخريطةُ الحراريّةُ تُلخّصُ السعةَ عبرَ القنواتِ والزمن
# - مقياسُ الألوانِ `RdBu_r`: الأحمرُ للموجبِ والأزرقُ للسالب
# - تُكشفُ عن أنماطٍ زمنيّةٍ مشتركةٍ بينَ القنوات
#
# </div>
